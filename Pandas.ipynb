# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
from pydataset import data

# %%
AQ = data('airquality')

# %%
AQ
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# 6     28.0      NaN  14.9    66      5    6
# 7     23.0    299.0   8.6    65      5    7
# 8     19.0     99.0  13.8    59      5    8
# 9      8.0     19.0  20.1    61      5    9
# 10     NaN    194.0   8.6    69      5   10
# 11     7.0      NaN   6.9    74      5   11
# 12    16.0    256.0   9.7    69      5   12
# 13    11.0    290.0   9.2    66      5   13
# 14    14.0    274.0  10.9    68      5   14
# 15    18.0     65.0  13.2    58      5   15
# 16    14.0    334.0  11.5    64      5   16
# 17    34.0    307.0  12.0    66      5   17
# 18     6.0     78.0  18.4    57      5   18
# 19    30.0    322.0  11.5    68      5   19
# 20    11.0     44.0   9.7    62      5   20
# ...

# %%
AQ.to_csv('airquality.csv', sep=',')

# %%
df = pd.read_csv(sep=',',filepath_or_buffer = 'airquality.csv', )

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
df.tail(n=10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 143         144   13.0    238.0  12.6    64      9   21
# 144         145   23.0     14.0   9.2    71      9   22
# 145         146   36.0    139.0  10.3    81      9   23
# 146         147    7.0     49.0  10.3    69      9   24
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
# Unnamed: 0    153 non-null int64
# Ozone         116 non-null float64
# Solar.R       146 non-null float64
# Wind          153 non-null float64
# Temp          153 non-null int64
# Month         153 non-null int64
# Day           153 non-null int64
# dtypes: float64(3), int64(4)
# memory usage: 8.4 KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind        Temp       Month  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean    77.000000   42.129310  185.931507    9.957516   77.882353    6.993464
# std     44.311398   32.987885   90.058422    3.523001    9.465270    1.416522
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     39.000000   18.000000  115.750000    7.400000   72.000000    6.000000
# 50%     77.000000   31.500000  205.000000    9.700000   79.000000    7.000000
# 75%    115.000000   63.250000  258.750000   11.500000   85.000000    8.000000
# max    153.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day
# count  153.000000
# mean    15.803922
# std      8.864520
# min      1.000000
# 25%      8.000000
# 50%     16.000000
# 75%     23.000000
# max     31.000000

# %%
df['Ozone'].value_counts(dropna=False)
# Out:
# NaN       37
#  23.0      6
#  21.0      4
#  13.0      4
#  20.0      4
#  18.0      4
#  14.0      4
#  16.0      4
#  7.0       3
#  11.0      3
#  44.0      3
#  9.0       3
#  28.0      3
#  32.0      3
#  30.0      2
#  85.0      2
#  24.0      2
#  39.0      2
#  35.0      2
#  37.0      2
#  45.0      2
#  97.0      2
#  59.0      2
#  78.0      2
#  73.0      2
#  12.0      2
#  36.0      2
#  64.0      2
#  1.0       1
#  4.0       1
#  135.0     1
#  115.0     1
#  29.0      1
#  6.0       1
#  71.0      1
#  34.0      1
#  8.0       1
#  19.0      1
#  46.0      1
#  49.0      1
#  122.0     1
#  47.0      1
#  91.0      1
#  96.0      1
#  84.0      1
#  118.0     1
#  76.0      1
#  168.0     1
#  31.0      1
#  22.0      1
#  65.0      1
#  110.0     1
#  89.0      1
#  66.0      1
#  40.0      1
#  50.0      1
#  82.0      1
#  52.0      1
#  108.0     1
#  80.0      1
#  63.0      1
#  79.0      1
#  61.0      1
#  48.0      1
#  27.0      1
#  10.0      1
# ...

# %%
for a,b in AQ.iterrows():
    print(a,b)
# Out:
# 1 Ozone       41.0
# Solar.R    190.0
# Wind         7.4
# Temp        67.0
# Month        5.0
# Day          1.0
# Name: 1, dtype: float64
# 2 Ozone       36.0
# Solar.R    118.0
# Wind         8.0
# Temp        72.0
# Month        5.0
# Day          2.0
# Name: 2, dtype: float64
# 3 Ozone       12.0
# Solar.R    149.0
# Wind        12.6
# Temp        74.0
# Month        5.0
# Day          3.0
# Name: 3, dtype: float64
# 4 Ozone       18.0
# Solar.R    313.0
# Wind        11.5
# Temp        62.0
# Month        5.0
# Day          4.0
# Name: 4, dtype: float64
# 5 Ozone       NaN
# Solar.R     NaN
# Wind       14.3
# Temp       56.0
# Month       5.0
# Day         5.0
# Name: 5, dtype: float64
# 6 Ozone      28.0
# Solar.R     NaN
# Wind       14.9
# Temp       66.0
# Month       5.0
# Day         6.0
# Name: 6, dtype: float64
# 7 Ozone       23.0
# Solar.R    299.0
# Wind         8.6
# Temp        65.0
# Month        5.0
# Day          7.0
# Name: 7, dtype: float64
# ...

# %%
df[['Ozone','Temp']]
# Out:
#      Ozone  Temp
# 0     41.0    67
# 1     36.0    72
# 2     12.0    74
# 3     18.0    62
# 4      NaN    56
# 5     28.0    66
# 6     23.0    65
# 7     19.0    59
# 8      8.0    61
# 9      NaN    69
# 10     7.0    74
# 11    16.0    69
# 12    11.0    66
# 13    14.0    68
# 14    18.0    58
# 15    14.0    64
# 16    34.0    66
# 17     6.0    57
# 18    30.0    68
# 19    11.0    62
# 20     1.0    59
# 21    11.0    73
# 22     4.0    61
# 23    32.0    61
# 24     NaN    57
# 25     NaN    58
# 26     NaN    57
# 27    23.0    67
# 28    45.0    81
# 29   115.0    79
# 30    37.0    76
# 31     NaN    78
# 32     NaN    74
# 33     NaN    67
# 34     NaN    84
# 35     NaN    85
# 36     NaN    79
# 37    29.0    82
# 38     NaN    87
# 39    71.0    90
# 40    39.0    87
# 41     NaN    93
# 42     NaN    92
# 43    23.0    82
# 44     NaN    80
# 45     NaN    79
# 46    21.0    77
# 47    37.0    72
# 48    20.0    65
# 49    12.0    73
# 50    13.0    76
# ...

# %%
df[1:3]
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3

# %%
df.loc[1:50,['Ozone','Temp']]
# Out:
#     Ozone  Temp
# 1    36.0    72
# 2    12.0    74
# 3    18.0    62
# 4     NaN    56
# 5    28.0    66
# 6    23.0    65
# 7    19.0    59
# 8     8.0    61
# 9     NaN    69
# 10    7.0    74
# 11   16.0    69
# 12   11.0    66
# 13   14.0    68
# 14   18.0    58
# 15   14.0    64
# 16   34.0    66
# 17    6.0    57
# 18   30.0    68
# 19   11.0    62
# 20    1.0    59
# 21   11.0    73
# 22    4.0    61
# 23   32.0    61
# 24    NaN    57
# 25    NaN    58
# 26    NaN    57
# 27   23.0    67
# 28   45.0    81
# 29  115.0    79
# 30   37.0    76
# 31    NaN    78
# 32    NaN    74
# 33    NaN    67
# 34    NaN    84
# 35    NaN    85
# 36    NaN    79
# 37   29.0    82
# 38    NaN    87
# 39   71.0    90
# 40   39.0    87
# 41    NaN    93
# 42    NaN    92
# 43   23.0    82
# 44    NaN    80
# 45    NaN    79
# 46   21.0    77
# 47   37.0    72
# 48   20.0    65
# 49   12.0    73
# 50   13.0    76

# %%
df.iloc[1:5,0:3]
# Out:
#    Unnamed: 0  Ozone  Solar.R
# 1           2   36.0    118.0
# 2           3   12.0    149.0
# 3           4   18.0    313.0
# 4           5    NaN      NaN

# %%
df.iloc[[1,50],0:3]
# Out:
#     Unnamed: 0  Ozone  Solar.R
# 1            2   36.0    118.0
# 50          51   13.0    137.0

# %%
df.iloc[1:5,[1,2,3]]
# Out:
#    Ozone  Solar.R  Wind
# 1   36.0    118.0   8.0
# 2   12.0    149.0  12.6
# 3   18.0    313.0  11.5
# 4    NaN      NaN  14.3

# %%
high_temp = df['Temp']>78
df[high_temp]
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 28           29   45.0    252.0  14.9    81      5   29
# 29           30  115.0    223.0   5.7    79      5   30
# 34           35    NaN    186.0   9.2    84      6    4
# 35           36    NaN    220.0   8.6    85      6    5
# 36           37    NaN    264.0  14.3    79      6    6
# 37           38   29.0    127.0   9.7    82      6    7
# 38           39    NaN    273.0   6.9    87      6    8
# 39           40   71.0    291.0  13.8    90      6    9
# 40           41   39.0    323.0  11.5    87      6   10
# 41           42    NaN    259.0  10.9    93      6   11
# 42           43    NaN    250.0   9.2    92      6   12
# 43           44   23.0    148.0   8.0    82      6   13
# 44           45    NaN    332.0  13.8    80      6   14
# 45           46    NaN    322.0  11.5    79      6   15
# 58           59    NaN     98.0  11.5    80      6   28
# 60           61    NaN    138.0   8.0    83      6   30
# ...

# %%
df[df['Temp']>78].shape
# Out:
# (79, 7)

# %%
df[(df['Temp']>78) & (df['Ozone'] > 42)]
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 28           29   45.0    252.0  14.9    81      5   29
# 29           30  115.0    223.0   5.7    79      5   30
# 39           40   71.0    291.0  13.8    90      6    9
# 61           62  135.0    269.0   4.1    84      7    1
# 62           63   49.0    248.0   9.2    85      7    2
# 65           66   64.0    175.0   4.6    83      7    5
# 67           68   77.0    276.0   5.1    88      7    7
# 68           69   97.0    267.0   6.3    92      7    8
# 69           70   97.0    272.0   5.7    92      7    9
# 70           71   85.0    175.0   7.4    89      7   10
# 76           77   48.0    260.0   6.9    81      7   16
# 78           79   61.0    285.0   6.3    84      7   18
# 79           80   79.0    187.0   5.1    87      7   19
# 80           81   63.0    220.0  11.5    85      7   20
# 84           85   80.0    294.0   8.6    86      7   24
# 85           86  108.0    223.0   8.0    85      7   25
# ...

# %%
[False,True] and [True,False]
# Out:
# [True, False]

# %%
import numpy as np
np.logical_and([False,True], [True, False])
# Out:
# array([False, False])

# %%
pd.Series([False, True]) & pd.Series([True, False])
